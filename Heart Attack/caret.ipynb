# %%
import seaborn as sns
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

# %%
heart = pd.read_csv('/Users/antoniobaio/Desktop/Progetti/ProgettiDS/statsmodel/Classificazione_clustering/Heart Attack/dataset/heart.csv')
heart.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output
# 0    0      1       1
# 1    0      2       1
# 2    0      2       1
# 3    0      2       1
# 4    0      2       1

# %%
heart.shape
# Out:
# (303, 14)

# %%
heart.drop_duplicates(keep='first', inplace=True)

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(heart, test_size=0.2, random_state=42)

# %%
from pycaret.classification import *
data = setup(train, target = 'output', normalize=True, test_data=test, session_id = 1999)
# Out:
# <style type="text/css">
# #T_1985c_row8_col1, #T_1985c_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1985c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1985c_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_1985c_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1985c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1985c_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_1985c_row0_col1" class="data row0 col1" >1999</td>
#     </tr>
#     <tr>
#       <th id="T_1985c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1985c_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1985c_row1_col1" class="data row1 col1" >output</td>
#     </tr>
#     <tr>
#       <th id="T_1985c_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
svm = create_model('rbfsvm')
evaluate_model(svm)
# Out:
# <style type="text/css">
# #T_a36d4_row10_col0, #T_a36d4_row10_col1, #T_a36d4_row10_col2, #T_a36d4_row10_col3, #T_a36d4_row10_col4, #T_a36d4_row10_col5, #T_a36d4_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_a36d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a36d4_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_a36d4_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_a36d4_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_a36d4_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_a36d4_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_a36d4_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_a36d4_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
plot_model(svm, plot = 'confusion_matrix')
plot_model(svm, plot = 'pr')
plot_model(svm, plot = 'auc')

# %%
predict_model(svm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_660a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_660a0_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_660a0_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_660a0_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_660a0_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_660a0_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_660a0_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_660a0_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_660a0_level0_col7" class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_660a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_660a0_row0_col0" class="data row0 col0" >SVM - Radial Kernel</td>
# ...

# %%
rf = create_model('rf')
evaluate_model(rf)
# Out:
# <style type="text/css">
# #T_ae04a_row10_col0, #T_ae04a_row10_col1, #T_ae04a_row10_col2, #T_ae04a_row10_col3, #T_ae04a_row10_col4, #T_ae04a_row10_col5, #T_ae04a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_ae04a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae04a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_ae04a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_ae04a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_ae04a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_ae04a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_ae04a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_ae04a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
# ...

# %%
predict_model(rf)
# Out:
#      age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 180   55    1   0     132   353    0        1       132     1      1.2    1
# 229   64    1   2     125   309    0        1       131     1      1.8    1
# 111   57    1   2     150   126    1        1       173     0      0.2    2
# 247   66    1   1     160   246    0        1       120     1      0.0    1
# 60    71    0   2     110   265    1        0       130     0      0.0    2
# ..   ...  ...  ..     ...   ...  ...      ...       ...   ...      ...  ...
# 250   51    1   0     140   298    0        1       122     1      4.2    1
# 104   50    1   2     129   196    0        1       163     0      0.0    2
# 300   68    1   0     144   193    1        1       141     0      3.4    1
# 194   60    1   2     140   185    0        0       155     0      3.0    1
# 185   44    1   0     112   290    0        0       153     0      0.0    2
#
# ...

# %%
best = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              17:12:01
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_f7572 th {
#   text-align: left;
# }
# ...

# %%
predictions = predict_model(best, data=heart)
predictions.head()
# Out:
#    age  sex  cp  trtbps  chol  fbs  restecg  thalachh  exng  oldpeak  slp  \
# 0   63    1   3     145   233    1        0       150     0      2.3    0
# 1   37    1   2     130   250    0        1       187     0      3.5    0
# 2   41    0   1     130   204    0        0       172     0      1.4    2
# 3   56    1   1     120   236    0        1       178     0      0.8    2
# 4   57    0   0     120   354    0        1       163     1      0.6    2
#
#    caa  thall  output  prediction_label  prediction_score
# 0    0      1       1                 0            0.8797
# 1    0      2       1                 0            0.9915
# 2    0      2       1                 1            0.9974
# 3    0      2       1                 1            0.9917
# 4    0      2       1                 1            0.9423

# %%
from pycaret.regression import *
regression = setup(heart, target = 'output', session_id = 123)
# Out:
# <style type="text/css">
# #T_ceedc_row8_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ceedc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ceedc_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_ceedc_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ceedc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ceedc_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_ceedc_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ceedc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ceedc_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ceedc_row1_col1" class="data row1 col1" >output</td>
#     </tr>
#     <tr>
#       <th id="T_ceedc_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best = compare_models()
# Out:
# <style type="text/css">
# #T_6b14f th {
#   text-align: left;
# }
# ...

# %%
print(best)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='squared_error',
#                     max_depth=None, max_features=1.0, max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_samples_leaf=1, min_samples_split=2,
#                     min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                     oob_score=False, random_state=123, verbose=0,
#                     warm_start=False)

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
